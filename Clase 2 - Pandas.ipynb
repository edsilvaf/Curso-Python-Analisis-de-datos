# %% [markdown]
# #Ejercicios Python
#
# #Mail: damiansilva14@hotmail.com
#
# **Notas de clase inspiradas en las clases de Lidia Norts de la Universidad de Alcalá**

# %% [markdown]
# #Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Ejercicio 1
#
# **Introducir una base de datos de Internet en un dataframe: https://forge.scilab.org/index.php/p/rdataset/source/tree/master/csv/rpart/kyphosis.csv**

# %%
data = pd.read_csv("kyphosis.csv",na_values='?', header=None)
print(data)
# Out:
#        0         1    2       3      4
# 0    NaN  Kyphosis  Age  Number  Start
# 1    1.0    absent   71       3      5
# 2    2.0    absent  158       3     14
# 3    3.0   present  128       4      5
# 4    4.0    absent    2       5      1
# 5    5.0    absent    1       4     15
# 6    6.0    absent    1       2     16
# 7    7.0    absent   61       2     17
# 8    8.0    absent   37       3     16
# 9    9.0    absent  113       2     16
# 10  10.0   present   59       6     12
# 11  11.0   present   82       5     14
# 12  12.0    absent  148       3     16
# 13  13.0    absent   18       5      2
# 14  14.0    absent    1       4     12
# 15  15.0    absent  168       3     18
# 16  16.0    absent    1       3     16
# 17  17.0    absent   78       6     15
# 18  18.0    absent  175       5     13
# 19  19.0    absent   80       5     16
# 20  20.0    absent   27       4      9
# 21  21.0    absent   22       2     16
# 22  22.0   present  105       6      5
# ...

# %%
#Verificacion de que es un dataframe
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Verificamos la tipoloogía de las variables
data.dtypes
# Out:
# 0    float64
# 1     object
# 2     object
# 3     object
# 4     object
# dtype: object

# %%
data.shape
# Out:
# (82, 5)

# %% [markdown]
# **Comprobración de si hay datos faltantes**

# %%
data.isnull().sum()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %% [markdown]
# **Obtén la longitud y anchuras medias por cada categoría (“body-style”)**

# %% [markdown]
# #Analisis exploratorio con Pandas

# %%
# miramos qué categorías tiene 'Age'
data[2].unique()
# Out:
# array(['Age', '71', '158', '128', '2', '1', '61', '37', '113', '59', '82',
#        '148', '18', '168', '78', '175', '80', '27', '22', '105', '96',
#        '131', '15', '9', '8', '100', '4', '151', '31', '125', '130',
#        '112', '140', '93', '52', '20', '91', '73', '35', '143', '97',
#        '139', '136', '121', '177', '68', '72', '120', '51', '102', '114',
#        '81', '118', '17', '195', '159', '127', '87', '206', '11', '178',
#        '157', '26', '42', '36'], dtype=object)

# %%
# indexamos las columnas que nos interesan
data_aux = data.loc[:,[0,1,4]]

# %%
data_aux
# Out:
#        0         1      4
# 0    NaN  Kyphosis  Start
# 1    1.0    absent      5
# 2    2.0    absent     14
# 3    3.0   present      5
# 4    4.0    absent      1
# 5    5.0    absent     15
# 6    6.0    absent     16
# 7    7.0    absent     17
# 8    8.0    absent     16
# 9    9.0    absent     16
# 10  10.0   present     12
# 11  11.0   present     14
# 12  12.0    absent     16
# 13  13.0    absent      2
# 14  14.0    absent     12
# 15  15.0    absent     18
# 16  16.0    absent     16
# 17  17.0    absent     15
# 18  18.0    absent     13
# 19  19.0    absent     16
# 20  20.0    absent      9
# 21  21.0    absent     16
# 22  22.0   present      5
# 23  23.0   present     12
# 24  24.0    absent      3
# 25  25.0   present      2
# 26  26.0    absent     13
# 27  27.0    absent      6
# 28  28.0    absent     14
# 29  29.0    absent     16
# ..   ...       ...    ...
# 52  52.0    absent     17
# 53  53.0   present      6
# 54  54.0    absent     17
# ...

# %%
# agrupamos por categoría de body-style, agregando la media del resto de columnas

bybody_style = data_aux.groupby(1)
bybody_style.mean()
# Out:
#                   0
# 1
# Kyphosis        NaN
# absent    40.968750
# present   41.117647

# %%
#Analiza el atributo de comienzo (“4”) y dibuja su histograma para apreciar si sigue alguna distribución concreta
data[4].describe()
# Out:
# count     82
# unique    17
# top       16
# freq      17
# Name: 4, dtype: object

# %%
# dibujamos su histograma
# %matplotlib inline
data[4].hist()
